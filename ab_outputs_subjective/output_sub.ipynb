# %%
import pandas as pd

# %%
df = pd.read_csv("paired_results_subjective.csv")
df
# Out:
#                task         subjective_item  n_pairs    mean_A    mean_B  \
# 0         add-plant              confidence       12  6.500000  6.750000
# 1         add-plant     error_recovery_ease       12  6.666667  6.916667
# 2         add-plant                   group       12  0.416667  0.416667
# 3         add-plant      navigation_clarity       12  7.000000  6.666667
# 4         add-plant       outcome_certainty       12  6.750000  6.833333
# 5         add-plant         perceived_speed       12  6.833333  6.416667
# 6   kiwi-favourites                 clarity       12  6.583333  6.916667
# 7   kiwi-favourites             findability       12  5.083333  6.666667
# 8   kiwi-favourites                   group       12  0.416667  0.416667
# 9   kiwi-favourites           intuitiveness       12  6.750000  6.750000
# 10  kiwi-favourites  knowledge_independence       12  3.333333  7.000000
# 11          sign-up              confidence       12  6.166667  6.500000
# ...
