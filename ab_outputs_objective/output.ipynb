# %%
import pandas as pd

# %%
df = pd.read_csv("paired_results_objective.csv")
df
# Out:
#                task            metric  n_pairs        mean_A        mean_B  \
# 0         tick-note  reaction_time_ms       12  23771.833333  11959.416667
# 1         tick-note            clicks       12      5.666667      4.416667
# 2         tick-note       error_score       12      0.791667      0.208333
# 3         add-plant  reaction_time_ms       12   5751.416667   4393.916667
# 4         add-plant            clicks       12      3.500000      3.250000
# 5         add-plant       error_score       12      0.333333      0.250000
# 6           sign-up  reaction_time_ms       12  49310.166667  74022.750000
# 7           sign-up            clicks       12     11.333333     16.416667
# 8           sign-up       error_score       12      1.125000      0.750000
# 9   kiwi-favourites  reaction_time_ms       12  33451.083333   7016.416667
# 10  kiwi-favourites            clicks       12      8.583333      4.666667
# ...
